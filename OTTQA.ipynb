# %%
import pandas as pd
from textblob import TextBlob
import re
from nltk.stem import WordNetLemmatizer
import csv

# %%
df = pd.read_csv('data/TyrionLannister_Tweets.csv')
df.head()
# Out:
#    username              date  retweets  favorites  \
# 0       NaN  02-05-2019 13:21         1          1
# 1       NaN  02-05-2019 12:49         0          0
# 2       NaN  02-05-2019 12:18         0          0
# 3       NaN  01-05-2019 11:01         0          3
# 4       NaN  01-05-2019 00:24         0          0
#
#                                                 text  geo mentions  \
# 0                                          Good call  NaN      NaN
# 1  if u die we all lost everyone and everything #...  NaN      NaN
# 2  # FanArt by trinket_truck! # TyrionLannister #...  NaN        @
# 3  FREE DELIVERY Order now and get # freedelivery...  NaN      NaN
# 4  Hey! Meet Khan from Pakistan Hi Peter! # GOT8 ...  NaN      NaN
#
#                   hashtags            id  \
# 0                      NaN           NaN
# 1        # # # # # # # # #  1.123990e+18
# 2              # # # # # #  1.123990e+18
# 3                      NaN           NaN
# ...

# %%
df = pd.read_csv("data/AryaStark_Sentiments.csv")
df
# Out:
#                                                   text sentiment  polarity  \
# 0    This is the best summary you will find of Seas...       Pos  0.250000
# 1    More tragic than the red wedding # got # gameo...       Neg -0.083333
# 2    # Repost gameofthrones.brasil ・・・ Pracarys! # ...       Neu  0.000000
# 3    Check out this awesome @ GameOfThrones Final S...       Pos  0.500000
# 4    If u saw this just know i wrote it just to see...       Pos  1.000000
# ..                                                 ...       ...       ...
# 690  Follow Share & Care # GameofThrones # GOT # GO...       Neu  0.000000
# 691  Follow Share & Care # GameofThrones # GOT # GO...       Neu  0.000000
# 692  Follow Share & Care # GameofThrones # GOT # GO...       Neu  0.000000
# 693  My poster Design of # GameOfThrones # GOT # Fo...       Neu  0.000000
# 694  Follow Share & Care # GameofThrones # GOT # GO...       Neu  0.000000
#
#      subjectivity                                         Preprocess
# ...
